# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#For ignoring warning
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\SUHANI\Downloads\cancerdataset1.csv")
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
import pandas as pd
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df=pd.read_csv(r"C:\Users\SUHANI\Downloads\cancerdataset1.csv")
df['Patient Id']=le.fit_transform(df['Patient Id'])
df['Age']=le.fit_transform(df['Age'])
df['Gender']=le.fit_transform(df['Gender'])
df['Air Pollution']=le.fit_transform(df['Air Pollution'])
df['Alcohol use']=le.fit_transform(df['Alcohol use'])
df['Dust Allergy']=le.fit_transform(df['Dust Allergy'])
df['OccuPational Hazards']=le.fit_transform(df['OccuPational Hazards'])
df['Genetic Risk']=le.fit_transform(df['Genetic Risk'])
df['chronic Lung Disease']=le.fit_transform(df['chronic Lung Disease'])
df['Balanced Diet']=le.fit_transform(df['Balanced Diet'])
df['Fatigue']=le.fit_transform(df['Fatigue'])
df['Weight Loss']=le.fit_transform(df['Weight Loss'])
df['Shortness of Breath']=le.fit_transform(df['Shortness of Breath'])
df['Wheezing']=le.fit_transform(df['Wheezing'])
df['Swallowing Difficulty']=le.fit_transform(df['Swallowing Difficulty'])
df['Clubbing of Finger Nails']=le.fit_transform(df['Clubbing of Finger Nails'])
df['Frequent Cold']=le.fit_transform(df['Frequent Cold'])
df['Dry Cough']=le.fit_transform(df['Dry Cough'])
df['Snoring']=le.fit_transform(df['Snoring'])
df['int-level']=le.fit_transform(df['int-level'])
df
# Out:
#      Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0             0   14       0              1            3             4
# 1             1    1       0              2            0             4
# 2             2   16       0              3            4             5
# 3             3   18       0              6            6             6
# 4             4   25       0              5            7             6
# ..          ...  ...     ...            ...          ...           ...
# 995         995   23       0              5            6             6
# 996         996   18       1              5            7             6
# 997         997    7       1              3            4             5
# 998         998    2       1              5            7             6
# 999         999   26       0              5            4             5
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='int-level', data=df,)
plt.title('Target Distribution')
# Out:
# Text(0.5, 1.0, 'Target Distribution')

# %%
def plot(col, df=df):
    return df.groupby(col)['int-level'].value_counts(normalize=True).unstack().plot(kind='bar', figsize=(8,5))
plot('Gender')
# Out:
# <Axes: xlabel='Gender'>

# %%
plot('Age')
# Out:
# <Axes: xlabel='Age'>

# %%
plot('Air Pollution')
# Out:
# <Axes: xlabel='Air Pollution'>

# %%
df_new=df.drop(columns=['Gender','Age', 'Air Pollution', 'Shortness of Breath'])
df_new
# Out:
#      Patient Id  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0             0            3             4                     3
# 1             1            0             4                     2
# 2             2            4             5                     4
# 3             3            6             6                     6
# 4             4            7             6                     6
# ..          ...          ...           ...                   ...
# 995         995            6             6                     6
# 996         996            7             6                     6
# 997         997            4             5                     4
# 998         998            7             6                     6
# 999         999            4             5                     4
#
#      Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0               2                     1              1        4        3
# ...

# %%
#Finding Correlation
cn=df_new.corr()
cn
# Out:
#                           Patient Id  Alcohol use  Dust Allergy  \
# Patient Id                  1.000000     0.041374      0.037960
# Alcohol use                 0.041374     1.000000      0.818644
# Dust Allergy                0.037960     0.818644      1.000000
# OccuPational Hazards        0.032355     0.878786      0.835860
# Genetic Risk                0.030725     0.877210      0.787904
# chronic Lung Disease        0.025177     0.763576      0.619556
# Balanced Diet               0.030743     0.653352      0.647197
# Obesity                     0.050584     0.669312      0.700676
# Smoking                     0.018407     0.547035      0.358691
# Passive Smoker              0.019517     0.592576      0.560002
# Chest Pain                  0.022210     0.717242      0.639983
# Coughing of Blood           0.049401     0.667612      0.625291
# Fatigue                     0.042527     0.226433      0.333198
# Weight Loss                 0.026393     0.207851      0.321756
# ...

# %%
#Correlation 
cmap=sns.diverging_palette(260,-10,s=50, l=75, n=6,as_cmap=True)
plt.subplots(figsize=(18,18))
sns.heatmap(cn,cmap=cmap,annot=True, square=True)
plt.show()

# %%
df_new['ALCDUSALL']=df_new['Alcohol use']*df_new['Dust Allergy']
df_new
# Out:
#      Patient Id  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0             0            3             4                     3
# 1             1            0             4                     2
# 2             2            4             5                     4
# 3             3            6             6                     6
# 4             4            7             6                     6
# ..          ...          ...           ...                   ...
# 995         995            6             6                     6
# 996         996            7             6                     6
# 997         997            4             5                     4
# 998         998            7             6                     6
# 999         999            4             5                     4
#
#      Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0               2                     1              1        4        3
# ...

# %%
#Splitting independent and dependent variables
X = df_new.drop('int-level', axis = 1)
y = df_new['int-level']

# %%
#Splitting data for training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=0)

# %%
#Fitting training data to the model
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression(random_state=0)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_lr_pred= lr_model.predict(X_test)
y_lr_pred
# Out:
# array([2, 1, 1, 2, 1, 1, 1, 1, 1, 0, 0, 2, 0, 2, 2, 0, 2, 1, 0, 1, 2, 1,
#        2, 2, 2, 2, 0, 2, 2, 1, 2, 0, 0, 2, 1, 1, 1, 1, 0, 0, 0, 2, 1, 1,
#        1, 1, 0, 0, 2, 1, 2, 1, 0, 2, 1, 1, 0, 0, 2, 2, 0, 2, 2, 2, 1, 1,
#        0, 2, 0, 2, 1, 1, 1, 1, 0, 0, 0, 1, 1, 2, 0, 2, 0, 2, 2, 1, 0, 1,
#        0, 2, 0, 0, 2, 0, 1, 0, 1, 2, 0, 2, 0, 2, 1, 0, 2, 1, 2, 0, 1, 2,
#        2, 2, 2, 1, 1, 0, 1, 0, 0, 1, 2, 0, 2, 0, 0, 1, 0, 0, 0, 0, 0, 1,
#        0, 0, 2, 1, 0, 2, 1, 2, 1, 0, 1, 1, 0, 2, 0, 0, 0, 0, 0, 0, 1, 2,
#        2, 2, 0, 1, 1, 0, 1, 2, 2, 2, 0, 0, 2, 0, 2, 1, 2, 2, 0, 0, 0, 1,
#        2, 2, 2, 1, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2,
#        2, 0, 2, 0, 2, 0, 0, 1, 1, 1, 1, 0, 1, 1, 1, 1, 0, 2, 1, 0, 0, 0,
#        2, 1, 1, 0, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 0, 2, 0, 1, 1, 1, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 1], dtype=int64)

# %%
#Model accuracy
from sklearn.metrics import classification_report, accuracy_score, f1_score
lr_cr=classification_report(y_test, y_lr_pred)
print(lr_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88        85
#            1       0.86      0.91      0.88        74
#            2       0.98      0.95      0.96        91
#
#     accuracy                           0.91       250
#    macro avg       0.91      0.91      0.91       250
# weighted avg       0.91      0.91      0.91       250

# %%
#Decision tree
#Fitting training data to the model
from sklearn.tree import DecisionTreeClassifier
dt_model= DecisionTreeClassifier(criterion='entropy', random_state=0)  
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#Predicting result using testing data
y_dt_pred= dt_model.predict(X_test)
y_dt_pred
# Out:
# array([2, 1, 1, 2, 0, 1, 1, 1, 1, 0, 0, 2, 0, 2, 2, 0, 2, 1, 0, 1, 2, 0,
#        2, 2, 2, 2, 0, 2, 2, 1, 2, 0, 0, 2, 1, 1, 1, 0, 2, 0, 1, 2, 1, 1,
#        1, 0, 0, 2, 2, 1, 2, 1, 0, 2, 1, 1, 0, 0, 2, 2, 0, 2, 2, 2, 1, 1,
#        0, 2, 2, 2, 1, 1, 1, 1, 0, 0, 0, 1, 1, 2, 0, 1, 0, 2, 2, 1, 0, 1,
#        0, 2, 1, 0, 2, 0, 1, 0, 1, 2, 0, 2, 1, 2, 1, 0, 2, 1, 2, 1, 1, 2,
#        2, 2, 2, 1, 0, 0, 1, 0, 0, 1, 2, 1, 2, 0, 0, 1, 0, 0, 0, 0, 0, 1,
#        0, 0, 2, 1, 0, 1, 1, 2, 1, 0, 1, 1, 0, 2, 0, 0, 0, 0, 0, 2, 1, 2,
#        2, 2, 0, 1, 1, 0, 1, 2, 2, 2, 0, 0, 2, 0, 2, 1, 2, 2, 0, 0, 0, 1,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2,
#        2, 0, 2, 0, 2, 0, 0, 1, 0, 1, 1, 0, 1, 1, 0, 0, 0, 2, 0, 0, 0, 2,
#        2, 0, 1, 0, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 0, 2, 0, 1, 1, 1, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 1], dtype=int64)

# %%
dt_cr=classification_report(y_test, y_dt_pred)
print(dt_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        74
#            2       1.00      1.00      1.00        91
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
#Fitting K-NN classifier to the training set  
from sklearn.neighbors import KNeighborsClassifier  
knn_model= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Predicting result using testing data
y_knn_pred= knn_model.predict(X_test)
y_knn_pred
# Out:
# array([2, 1, 1, 2, 1, 1, 0, 0, 1, 0, 0, 2, 1, 2, 2, 0, 2, 1, 1, 2, 0, 1,
#        2, 2, 2, 2, 0, 2, 2, 0, 2, 0, 0, 2, 1, 1, 1, 0, 0, 0, 1, 2, 1, 2,
#        2, 2, 0, 0, 2, 2, 2, 1, 0, 2, 1, 0, 0, 0, 2, 2, 1, 2, 1, 2, 1, 1,
#        0, 2, 0, 1, 1, 1, 1, 2, 0, 1, 0, 1, 0, 2, 0, 1, 0, 2, 1, 1, 0, 1,
#        0, 2, 2, 0, 2, 0, 1, 0, 1, 2, 0, 2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 2,
#        2, 2, 2, 1, 0, 0, 1, 0, 0, 1, 2, 1, 2, 0, 0, 1, 0, 0, 0, 0, 0, 1,
#        0, 0, 2, 1, 1, 1, 1, 2, 1, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 1, 2,
#        2, 2, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0, 2, 0, 2, 1, 0, 2, 0, 0, 0, 1,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 1, 0, 2, 0, 2, 1, 0, 2,
#        2, 0, 1, 0, 2, 1, 0, 1, 2, 1, 1, 0, 0, 0, 2, 1, 1, 2, 0, 0, 0, 0,
#        2, 2, 1, 0, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 0, 2, 1, 1, 1, 1, 2, 0,
#        2, 1, 2, 2, 2, 0, 0, 2], dtype=int64)

# %%
#Model accuracy
knn_cr=classification_report(y_test, y_knn_pred)
print(knn_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        85
#            1       0.74      0.74      0.74        74
#            2       0.84      0.84      0.84        91
#
#     accuracy                           0.80       250
#    macro avg       0.79      0.79      0.79       250
# weighted avg       0.80      0.80      0.80       250

# %%
#Fitting Gaussian Naive Bayes classifier to the training set  
from sklearn.naive_bayes import GaussianNB
gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predicting result using testing data
y_gnb_pred= gnb_model.predict(X_test)
y_gnb_pred
# Out:
# array([2, 1, 1, 2, 0, 1, 1, 1, 1, 0, 0, 2, 0, 2, 2, 0, 2, 1, 0, 2, 1, 2,
#        2, 2, 2, 2, 0, 2, 2, 1, 2, 0, 0, 2, 1, 1, 1, 0, 1, 0, 1, 2, 1, 2,
#        1, 0, 0, 1, 2, 2, 2, 1, 0, 2, 1, 1, 0, 0, 2, 2, 0, 2, 1, 2, 1, 1,
#        0, 2, 1, 2, 1, 2, 1, 1, 1, 0, 0, 1, 1, 2, 1, 2, 0, 2, 2, 1, 0, 1,
#        0, 2, 1, 0, 2, 0, 1, 0, 1, 2, 0, 2, 1, 2, 1, 0, 2, 1, 2, 2, 1, 2,
#        2, 2, 2, 2, 0, 0, 1, 0, 0, 1, 2, 1, 2, 0, 0, 2, 1, 0, 0, 0, 0, 1,
#        0, 0, 2, 1, 0, 1, 1, 2, 1, 0, 1, 1, 0, 2, 0, 0, 0, 0, 0, 1, 1, 2,
#        2, 2, 0, 1, 1, 1, 1, 2, 2, 2, 1, 0, 2, 0, 2, 1, 2, 2, 0, 0, 0, 1,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2,
#        2, 1, 2, 0, 2, 0, 0, 1, 2, 1, 1, 0, 1, 1, 2, 0, 0, 2, 0, 0, 0, 1,
#        2, 2, 1, 0, 1, 1, 0, 1, 2, 2, 1, 1, 2, 2, 0, 2, 0, 1, 1, 1, 2, 0,
#        2, 1, 2, 2, 2, 2, 0, 1], dtype=int64)

# %%
#Model accuracy
gnb_cr=classification_report(y_test, y_gnb_pred)
print(gnb_cr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Model accuracy
# ----> 2 gnb_cr=classification_report(y_test, y_gnb_pred)
#       3 print(gnb_cr)
#
# NameError: name 'classification_report' is not defined
